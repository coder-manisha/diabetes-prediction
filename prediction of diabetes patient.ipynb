# %% [markdown]
# # step1: import related dependencies(libraries)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # step2 : loading the data using pandas
# ## we can get data from any govt organizations or internet or non-orgs ..etc

# %%
df = pd.read_excel('pima-data.xlsx')
df.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  thickness  insulin   bmi  diab_pred  \
# 0         6           148            72         35        0  33.6      0.627
# 1         1            85            66         29        0  26.6      0.351
# 2         8           183            64          0        0  23.3      0.672
# 3         1            89            66         23       94  28.1      0.167
# 4         0           137            40         35      168  43.1      2.288
#
#    age  diabetes_orig    skin  has_diabetes  diabetes
# 0   50              1  1.3790          True      True
# 1   31              0  1.1426         False     False
# 2   32              1  0.0000          True      True
# 3   21              0  0.9062         False     False
# 4   33              1  1.3790          True      True

# %%
len(df)
# Out:
# 768

# %% [markdown]
# # step3 : cleaning the data

# %% [markdown]
# ## a) checking the null values present in a dataframe

# %%
df.isnull().values.any()
# Out:
# np.False_

# %%
df.isnull().sum()
# glucose_conc     0---> if 0 means dont't have any null values in a df
# Out:
# num_preg         0
# glucose_conc     0
# diastolic_bp     0
# thickness        0
# insulin          0
# bmi              0
# diab_pred        0
# age              0
# diabetes_orig    0
# skin             0
# has_diabetes     0
# diabetes         0
# dtype: int64

# %%
## if null values are presetnt then we have to use dropna or fillna
## if u have data then use dropna otherwise fillna

# %% [markdown]
# ## b) finding the corelation between two columns

# %%
##first how many columns are there-->12

# %%
corr = df.corr() # pandas data frame correlation function
fig,ax = plt.subplots(figsize=(12,12))
cmap = 'plasma'
ax.matshow(corr,cmap = cmap)
plt.xticks(range(len(corr.columns)),corr.columns,rotation=60)
plt.yticks(range(len(corr.columns)),corr.columns)
plt.show()

# %% [markdown]
# ### c) drop the coreltaed columns

# %%
#we are going to remove thickness,diabetes_orig,has_diabetes

# %%
df.drop('thickness',axis=1,inplace=True)
df.drop('has_diabetes',axis=1,inplace=True)
df.drop('diabetes_orig',axis=1,inplace=True)

# %%
df.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  insulin   bmi  diab_pred  age  \
# 0         6           148            72        0  33.6      0.627   50
# 1         1            85            66        0  26.6      0.351   31
# 2         8           183            64        0  23.3      0.672   32
# 3         1            89            66       94  28.1      0.167   21
# 4         0           137            40      168  43.1      2.288   33
#
#      skin  diabetes
# 0  1.3790      True
# 1  1.1426     False
# 2  0.0000      True
# 3  0.9062     False
# 4  1.3790      True

# %%
corr = df.corr()
fig,ax = plt.subplots(figsize=(12,12))
cmap = 'plasma'                                          
ax.matshow(corr,cmap = cmap)
plt.xticks(range(len(corr.columns)),corr.columns,rotation=60)
plt.yticks(range(len(corr.columns)),corr.columns)
plt.show()

# %% [markdown]
# ## d) replacing the string data with 0 and 1

# %%
#creating a dictionary to convert True to 1 and False to 0
# want to replace True and False in the  diabetes column

dict1 = {
'diabetes':[True,False]
}
 # In place of True place with 1 and False with 0

dict2 = {'diabetes':[1,0]
        }
# use the replace function and inplace=True this will affect the real data
df['diabetes']=df['diabetes'].replace({True: 1, False: 0})
# Out:
# C:\Users\Manisha Kumari\AppData\Local\Temp\ipykernel_23280\3627531798.py:12: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['diabetes']=df['diabetes'].replace({True: 1, False: 0})

# %%
df.head()
# Out:
#    num_preg  glucose_conc  diastolic_bp  insulin   bmi  diab_pred  age  \
# 0         6           148            72        0  33.6      0.627   50
# 1         1            85            66        0  26.6      0.351   31
# 2         8           183            64        0  23.3      0.672   32
# 3         1            89            66       94  28.1      0.167   21
# 4         0           137            40      168  43.1      2.288   33
#
#      skin  diabetes
# 0  1.3790         1
# 1  1.1426         0
# 2  0.0000         1
# 3  0.9062         0
# 4  1.3790         1

# %%
## checking proportion of diabetes and non-diabetes data

num_true = len(df.loc[df['diabetes'] == 1])
num_false = len(df.loc[df['diabetes'] == 0])
print(f'num_true = {num_true}')
print(f'num_false = {num_false}')
per_num_true = (num_true/(num_true+num_false))*100
print(per_num_true)
per_num_false = (num_false/(num_true+num_false))*100
print(per_num_false)
# Out:
# num_true = 268
# num_false = 500
# 34.89583333333333
# 65.10416666666666

# %% [markdown]
# ## if we observe 64:35 is a good percentage

# %% [markdown]
# ## step 4 Train test split

# %%
from sklearn.model_selection import train_test_split
input_columns = ['num_preg','glucose_conc','diastolic_bp','insulin','bmi','diab_pred','age','skin']
output_columns = ['diabetes']
x = df[input_columns].values
y = df[output_columns].values
spilt_test_size = 0.3
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = spilt_test_size,random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (537, 8)
# (537, 1)
# (231, 8)
# (231, 1)

# %%
# make sure training data and testing data is 70% and 30%

print('{0:0.2f}% in training set'.format((len(x_train)/len(df.index))*100))
print('{0:0.2f}% in training set'.format((len(x_test)/len(df.index))*100))
# Out:
# 69.92% in training set
# 30.08% in training set

# %%
print('training true:{0} ({1:0.2f}%)'.format(len(y_train[y_train[ : ] == 1]),len(y_train[y_train[ : ] ==
1])/len(y_train) * 100))

print('training False:{0} ({1:0.2f}%)'.format(len(y_train[y_train[ : ] == 0]),len(y_train[y_train[ : ] ==
0])/len(y_train) * 100))

print('Test true:{0} ({1:0.2f}%)'.format(len(y_test[y_test[ : ] == 1]),len(y_test[y_test[ : ] ==
1])/len(y_train) * 100))

print('Test false:{0} ({1:0.2f}%)'.format(len(y_test[y_test[ : ] == 0]),len(y_test[y_test[ : ] ==
0])/len(y_train) * 100))
# Out:
# training true:188 (35.01%)
# training False:349 (64.99%)
# Test true:80 (14.90%)
# Test false:151 (28.12%)

# %%
total_num_preg = len(df.loc[df['num_preg']== 0])
print(f'number of Rows missing in num_preg column : {total_num_preg}')

total_glucose_conc = len(df.loc[df['glucose_conc']==0])
print(f'number of Rows missing in glucose_conc column : {total_glucose_conc}')
total_diastolic_bp = len(df.loc[df['diastolic_bp']==0])
print(f'number of Rows missing in diastolic_bp column : {total_diastolic_bp}')
total_insulin = len(df.loc[df['insulin']==0])
print(f'number of Rows missing in insulin column : {total_insulin}')
total_bmi = len(df.loc[df['bmi']==0])
print(f'number of Rows missing in bmi column : {total_bmi}')
total_diab_pred = len(df.loc[df['diab_pred']==0])
print(f'number of Rows missing in diab_pred column : {total_diab_pred}')
total_age = len(df.loc[df['age'] ==0])
print(f'number of rows missing in age : {total_age}')
# Out:
# number of Rows missing in num_preg column : 111
# number of Rows missing in glucose_conc column : 5
# number of Rows missing in diastolic_bp column : 35
# number of Rows missing in insulin column : 374
# number of Rows missing in bmi column : 11
# number of Rows missing in diab_pred column : 0
# number of rows missing in age : 0

# %% [markdown]
# # step 5 Training the model

# %%
#lets fill 0's with valid data (either mean or mode)

# %%
from sklearn.impute import SimpleImputer
fill_zeros = SimpleImputer(missing_values=0,strategy='mean')
x_train = fill_zeros.fit_transform(x_train)
x_test = fill_zeros.fit_transform(x_test)

# %%
x_train[0:10]
# Out:
# array([[1.00000000e+00, 9.50000000e+01, 6.00000000e+01, 5.80000000e+01,
#         2.39000000e+01, 2.60000000e-01, 2.20000000e+01, 7.09200000e-01],
#        [5.00000000e+00, 1.05000000e+02, 7.20000000e+01, 3.25000000e+02,
#         3.69000000e+01, 1.59000000e-01, 2.80000000e+01, 1.14260000e+00],
#        [4.34056399e+00, 1.35000000e+02, 6.80000000e+01, 2.50000000e+02,
#         4.23000000e+01, 3.65000000e-01, 2.40000000e+01, 1.65480000e+00],
#        [4.00000000e+00, 1.31000000e+02, 6.80000000e+01, 1.66000000e+02,
#         3.31000000e+01, 1.60000000e-01, 2.80000000e+01, 8.27400000e-01],
#        [1.00000000e+00, 1.03000000e+02, 3.00000000e+01, 8.30000000e+01,
#         4.33000000e+01, 1.83000000e-01, 3.30000000e+01, 1.49720000e+00],
#        [2.00000000e+00, 8.20000000e+01, 5.20000000e+01, 1.15000000e+02,
#         2.85000000e+01, 1.69900000e+00, 2.50000000e+01, 8.66800000e-01],
#        [3.00000000e+00, 1.28000000e+02, 7.80000000e+01, 1.55333333e+02,
#         2.11000000e+01, 2.68000000e-01, 5.50000000e+01, 1.12871227e+00],
#        [1.00000000e+00, 1.22000000e+02, 6.40000000e+01, 1.56000000e+02,
#         3.51000000e+01, 6.92000000e-01, 3.00000000e+01, 1.26080000e+00],
#        [4.34056399e+00, 1.38000000e+02, 7.22413127e+01, 1.55333333e+02,
#         3.63000000e+01, 9.33000000e-01, 2.50000000e+01, 1.12871227e+00],
#        [4.34056399e+00, 1.25000000e+02, 6.80000000e+01, 1.55333333e+02,
#         2.47000000e+01, 2.06000000e-01, 2.10000000e+01, 1.12871227e+00]])

# %%
from sklearn.naive_bayes import GaussianNB  
nb_model = GaussianNB() #creating object for GaussianNB Class
nb_model.fit(x_train,y_train.ravel()) # Training a model --> fit() is used || ravel()-->generates 2d array
# Out:
# GaussianNB()

# %%
#lets test the algorithm's accuracy with the training data itself

# %%
from sklearn import metrics  # metrics module --> calculates accuracy
nb_predict_model = nb_model.predict(x_train) # Testing a model
print(f'Predicted accuracy { metrics.accuracy_score(y_train,nb_predict_model) }') # Accuracy
# Out:
# Predicted accuracy 0.7541899441340782

# %% [markdown]
# ## step 6 - Testing the model

# %%
from sklearn import metrics
nb_predict_test = nb_model.predict(x_test)
print(f'Predicted accuracy { metrics.accuracy_score(y_test,nb_predict_test) }')
# Out:
# Predicted accuracy 0.7359307359307359

# %% [markdown]
# ### confusion matrix -- > we can analyze the performance

# %%
print(f'{ metrics.confusion_matrix(y_test,nb_predict_test)}')
# Out:
# [[118  33]
#  [ 28  52]]

# %%
print(f'{ metrics.classification_report(y_test,nb_predict_test)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.79       151
#            1       0.61      0.65      0.63        80
#
#     accuracy                           0.74       231
#    macro avg       0.71      0.72      0.71       231
# weighted avg       0.74      0.74      0.74       231

# %% [markdown]
# ### conclusion :  final observation of naive bayes algor--> accuracy 73% , recall 81%
# ### note : type 2 error should be less compared to type 1 error

# %%
#lets try RandomForest model

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42) # creating object for RandomForestClassifier class
rf_model.fit(x_train,y_train.ravel()) # Training a machine
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn import metrics
rf_predict_model = rf_model.predict(x_train) # Testing a model --> predict() is used
print(f'Predicted accuracy { metrics.accuracy_score(y_train,rf_predict_model) }')
# Out:
# Predicted accuracy 1.0

# %%
from sklearn import metrics
rf_predict_test =rf_model.predict(x_test)
print(f'Predicted accuracy { metrics.accuracy_score(y_test,rf_predict_test) }')
# Out:
# Predicted accuracy 0.7532467532467533

# %%
#lets see confusion matrix and classification report

# %%
print(f'{ metrics.confusion_matrix(y_test,rf_predict_test)}')
# Out:
# [[120  31]
#  [ 26  54]]

# %%
print(f'{ metrics.classification_report(y_test,rf_predict_test)}')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81       151
#            1       0.64      0.68      0.65        80
#
#     accuracy                           0.75       231
#    macro avg       0.73      0.73      0.73       231
# weighted avg       0.76      0.75      0.75       231

# %%
# lets solve with logistics regression
from sklearn.linear_model import LogisticRegression
lr_model = LogisticRegression(class_weight='balanced',C = 0.2 , max_iter = 1000) #c is hyper parameter value
lr_model.fit(x_train,y_train.ravel())
lr_predict_test = lr_model.predict(x_test)

# training metrics

print('accuracy : {0:4f}'.format(metrics.accuracy_score(y_test,lr_predict_test)))
print('  ')
print(metrics.confusion_matrix(y_test,lr_predict_test))
print(' ')
print('classification report')
print(metrics.classification_report(y_test,lr_predict_test))
# Out:
# accuracy : 0.688312
#
# [[108  43]
#  [ 29  51]]
#
# classification report
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75       151
#            1       0.54      0.64      0.59        80
#
#     accuracy                           0.69       231
#    macro avg       0.67      0.68      0.67       231
# weighted avg       0.70      0.69      0.69       231

# %%
from sklearn.neighbors import KNeighborsClassifier
k_neighbor = KNeighborsClassifier()
k_neighbor.fit(x_train,y_train.ravel())
# Out:
# KNeighborsClassifier()

# %%
x_pred = k_neighbor.predict(x_test)
print(f'Accuracy = {metrics.accuracy_score(y_test,x_pred)}')
print(f'Confusion matrix = \n {metrics.confusion_matrix(y_test,x_pred)}')
# Out:
# Accuracy = 0.7359307359307359
# Confusion matrix =
#  [[119  32]
#  [ 29  51]]

# %%
#Class Report

# %%
from sklearn.svm import SVC
support = SVC()
support.fit(x_train,y_train.ravel())
# Out:
# SVC()

# %%
x_pred = support.predict(x_test)
print(f'Accuracy = {metrics.accuracy_score(y_test,x_pred)} ')
print(f'Confusion matrix = \n {metrics.confusion_matrix(y_test,x_pred)}')
# Out:
# Accuracy = 0.7402597402597403
# Confusion matrix =
#  [[133  18]
#  [ 42  38]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
standardized_data = scaler.transform(x)
print(standardized_data)
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.46849198  1.4259954
#    0.90726993]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.36506078 -0.19067191
#    0.53090156]
#  [ 1.23388019  1.94372388 -0.26394125 ...  0.60439732 -0.10558415
#   -1.28821221]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.68519336 -0.27575966
#    0.15453319]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.37110101  1.17073215
#   -1.28821221]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.47378505 -0.87137393
#    0.65635768]]

# %%
support_model_test = support.predict(x_test) # Testing a model

input_data = [8,183,64,0,23.3,0.672,32,0.0000]
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
std_data = scaler.transform(input_data_reshaped)
print(std_data)
support_model_test = support.predict(std_data)
print(support_model_test)
# Out:
# [[ 1.23388019  1.94372388 -0.26394125 -0.69289057 -1.10325546  0.60439732
#   -0.10558415 -1.28821221]]
# [0]

# %% [markdown]
# # final conclusion:we are suggesting randomforest algorithm for this project as the accuracy is 75% and recall value is 82% which is higher than other algorithms (i.e naive bayes and logistic regression algorithm,etc..)
